# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as matplotlib
import pandas as pd
matplotlib.rcParams['figure.figsize'] = [18, 20]
df_006 = pd.read_csv("/home/fouriaux/Devel/reaching_ftb/hh/data/cn.csv")
potential_006 = df_006[["time(ms)", "potential(mV)"]].copy()
potential_006 = potential_006.set_index("time(ms)")
gates_006 = df_006[["time(ms)", "n","m","h", "g"]]
gates_006 = gates_006.set_index("time(ms)")
plt.subplot(2,1,1)
header = list(potential_006)
hh_v = plt.plot (potential_006)
plt.legend(iter(hh_v), header)
plt.title("membrane potential for timestep dt = 0.06")
plt.xlabel("time (ms)")
plt.ylabel("potential (mv)")
plt.subplot(2,1,2)
header = list(gates_006)
plt.title("gates and conductance for timestep dt = 0.065")
hh_v = plt.plot (gates_006)
plt.legend(iter(hh_v), header)
plt.xlabel("time (ms)")
# Out:
# Text(0.5,0,'time (ms)')

# %%
df_006 = pd.read_csv("/home/fouriaux/Devel/reaching_ftb/hh/data/cn_2.csv")
potential_006 = df_006[["time(ms)", "potential(mV)"]].copy()
potential_006 = potential_006.set_index("time(ms)")
gates_006 = df_006[["time(ms)", "n","m","h", "g"]]
gates_006 = gates_006.set_index("time(ms)")
plt.subplot(2,1,1)
header = list(potential_006)
hh_v = plt.plot (potential_006)
plt.legend(iter(hh_v), header)
plt.title("membrane potential for timestep dt = 0.06")
plt.xlabel("time (ms)")
plt.ylabel("potential (mv)")
plt.subplot(2,1,2)
header = list(gates_006)
plt.title("gates and conductance for timestep dt = 0.065")
hh_v = plt.plot (gates_006)
plt.legend(iter(hh_v), header)
plt.xlabel("time (ms)")
# Out:
# Text(0.5,0,'time (ms)')

# %%
df = pd.read_csv("/home/fouriaux/Devel/reaching_ftb/hh/data/cn_3.csv")
potential = df[["time(ms)", "potential(mV)"]].copy()
potential = potential.set_index("time(ms)")
gates = df[["time(ms)", "n","m","h", "g"]]
gates = gates.set_index("time(ms)")
plt.subplot(2,1,1)
header = list(potential)
hh_v = plt.plot (potential)
plt.legend(iter(hh_v), header)
plt.title("membrane potential for timestep dt = 0.025")
plt.xlabel("time (ms)")
plt.ylabel("potential (mv)")
plt.subplot(2,1,2)
header = list(gates)
plt.title("gates and conductance for timestep dt = 0.025")
hh_v = plt.plot (gates)
plt.legend(iter(hh_v), header)
plt.xlabel("time (ms)")
plt.show()

# %%
df_04 = pd.read_csv("/home/fouriaux/Devel/reaching_ftb/hh/data/cn_4.csv")
df_03 = pd.read_csv("/home/fouriaux/Devel/reaching_ftb/hh/data/cn_3.csv")
df_03 = df_03.rename(columns={"potential(mV)":"dt=0.025"})
potential_03 = df_03[["time(ms)", "dt=0.025"]].copy()
potential_03 = potential_03.set_index("time(ms)")

potential_04 = df_04[["time(ms)", "dt=0.0025"]].copy()
potential_04 = potential_04.set_index("time(ms)")

header = list(potential_03)
hh_v = plt.plot (potential_03)
plt.legend(iter(hh_v), header)
plt.title("Crank Nicholson method applied on HH model for different timesteps dt")
plt.xlabel("time (ms)")
plt.ylabel("potential (mv)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-411e11dab0dc> in <module>()
#       5 potential_03 = potential_03.set_index("time(ms)")
#       6
# ----> 7 potential_04 = df_04[["time(ms)", "dt=0.0025"]].copy()
#       8 potential_04 = potential_04.set_index("time(ms)")
#       9
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# ...

# %%
fe_005 = pd.read_csv("/home/fouriaux/Devel/reaching_ftb/hh/data/fe_dt_005.csv")
fe_potential_005 = fe_005[["time(ms)", "potential(mV)"]].copy()
fe_potential_005 = fe_potential_005.set_index("time(ms)")
cn_005 = pd.read_csv("/home/fouriaux/Devel/reaching_ftb/hh/data/cn_005.csv")
cn_potential_005 = cn_005[["time(ms)", "potential(mV)"]].copy()
cn_potential_005 = cn_potential_005.set_index("time(ms)")
cn_potential_005 = cn_potential_005.rename(columns={"potential(mV)":"cn"})
fe_potential_005 = fe_potential_005.rename(columns={"potential(mV)":"fe"})

potential_005 = pd.concat([fe_potential_005, cn_potential_005])

header = list(potential_005)
hh_v = plt.plot (potential_005)
plt.legend(iter(hh_v), header)
plt.title("Crank Nicholson method applied on HH model for different timesteps dt")
plt.xlabel("time (ms)")
plt.ylabel("potential (mv)")
plt.show()

# %%
fe_005 = pd.read_csv("/home/fouriaux/Devel/reaching_ftb/hh/data/fe_0005.csv")
fe_potential_005 = fe_005[["time(ms)", "potential(mV)"]].copy()
fe_potential_005 = fe_potential_005.set_index("time(ms)")
cn_005 = pd.read_csv("/home/fouriaux/Devel/reaching_ftb/hh/data/cn_0005.csv")
cn_potential_005 = cn_005[["time(ms)", "potential(mV)"]].copy()
cn_potential_005 = cn_potential_005.set_index("time(ms)")
cn_potential_005 = cn_potential_005.rename(columns={"potential(mV)":"cn"})
fe_potential_005 = fe_potential_005.rename(columns={"potential(mV)":"fe"})

potential_005 = pd.concat([fe_potential_005, cn_potential_005])

header = list(potential_005)
hh_v = plt.plot (potential_005)
plt.legend(iter(hh_v), header)
plt.title("Crank Nicholson method applied on HH model for different timesteps dt")
plt.xlabel("time (ms)")
plt.ylabel("potential (mv)")
plt.show()

# %%
fe_005 = pd.read_csv("/home/fouriaux/Devel/reaching_ftb/hh/data/fe_dt_005.csv")
fe_gates_005 = fe_005[["time(ms)", "g"]].copy()
fe_gates_005 = fe_gates_005.set_index("time(ms)")
cn_005 = pd.read_csv("/home/fouriaux/Devel/reaching_ftb/hh/data/cn_005.csv")
cn_gates_005 = cn_005[["time(ms)", "g"]].copy()
cn_gates_005 = cn_gates_005.set_index("time(ms)")
cn_gates_005 = cn_gates_005.rename(columns={"g":"cn"})
fe_gates_005 = fe_gates_005.rename(columns={"g":"fe"})

gates_005 = pd.concat([fe_gates_005, cn_gates_005])

header = list(gates_005)
hh_v = plt.plot (gates_005)
plt.legend(iter(hh_v), header)
plt.title("Crank Nicholson method applied on HH model for different timesteps dt")
plt.xlabel("time (ms)")
plt.ylabel("gates (mv)")
plt.show()
